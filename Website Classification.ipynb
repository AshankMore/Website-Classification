# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import string
from nltk.corpus import stopwords
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
website_df=pd.read_csv('../Downloads/website_classification.csv')
website_df.head()
# Out:
#   Unnamed: 0                                        website_url  \
# 0          0     https://www.booking.com/index.html?aid=1743217
# 1          1                   https://travelsites.com/expedia/
# 2          2               https://travelsites.com/tripadvisor/
# 3          3              https://www.momondo.in/?ispredir=true
# 4          4  https://www.ebookers.com/?AFFCID=EBOOKERS-UK.n...
#
#                                 cleaned_website_text Category
# 0  official site good hotel accommodation big sav...   Travel
# 1  expedia hotel book sites like use vacation wor...   Travel
# 2  tripadvisor hotel book sites like previously d...   Travel
# 3  cheap flights search compare flights momondo f...   Travel
# 4  bot create free account create free account si...   Travel

# %%
website_df = website_df.dropna()

# %%
print('Shape of dataframe:',website_df.shape)
print('Columns in dataframe:',website_df.columns)
# Out:
# Shape of dataframe: (1390, 3)
# Columns in dataframe: Index(['website_url', 'cleaned_website_text', 'Category'], dtype='object')

# %%
website_df.drop('Unnamed: 0',axis=1,inplace=True)   #Dropping the unnecessary column
website_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-27235e1fa06a> in <module>
# ----> 1 website_df.drop('Unnamed: 0',axis=1,inplace=True)   #Dropping the unnecessary column
#       2 website_df.head()
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
website_df.isnull().sum()
# Out:
# website_url             0
# cleaned_website_text    0
# Category                0
# dtype: int64

# %%
df_a=website_df.groupby('Category').count().sort_values(by='Category',ascending=True)
df_a.index
# Out:
# Index(['Adult', 'Business/Corporate', 'Computers and Technology', 'E-Commerce',
#        'Education', 'Food', 'Forums', 'Games', 'Health and Fitness',
#        'Law and Government', 'News', 'Photography',
#        'Social Networking and Messaging', 'Sports', 'Streaming Services',
#        'Travel'],
#       dtype='object', name='Category')

# %%
df_a
# Out:
#                                  website_url  cleaned_website_text
# Category
# Adult                                     15                    15
# Business/Corporate                       109                   109
# Computers and Technology                  93                    93
# E-Commerce                               102                   102
# Education                                109                   109
# Food                                      91                    91
# Forums                                    16                    16
# Games                                     98                    98
# Health and Fitness                        96                    96
# Law and Government                        83                    83
# News                                      92                    92
# Photography                               91                    91
# Social Networking and Messaging           83                    83
# Sports                                   103                   103
# Streaming Services                       103                   103
# Travel                                   106                   106

# %%
sns.countplot(y=website_df['Category'],order=website_df['Category'].value_counts().index[:16])

# %%
#workcloud

from wordcloud import WordCloud,STOPWORDS
content=''
stopwords_df=set(STOPWORDS)

for char in website_df['cleaned_website_text']:
    tokens=char.split(' ')
    
    content=content+' '.join(tokens)+' '

wordcloud_df=WordCloud(width=800,height=600,background_color='white',stopwords=stopwords_df).generate(content)
plt.figure(figsize=(8,8))
plt.axis('off')
plt.imshow(wordcloud_df)

# %%
#Education
sum_ed=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Education'):
        a= len(website_df['cleaned_website_text'][i])
        sum_ed=sum_ed+a
print('Total number of words including all the educational websites: ', sum_ed)



#Business/Corporate
sum_business=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Business/Corporate'):
        a= len(website_df['cleaned_website_text'][i])
        sum_business=sum_business+a
print('Total number of words including all the Business/Corporate website: ', sum_business)


#Travel
sum_travel=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Travel'):
        a= len(website_df['cleaned_website_text'][i])
        sum_travel=sum_travel+a
print('Total number of words including all the travel websites: ', sum_travel)


#Streaming services
sum_stream=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Streaming Services'):
        a= len(website_df['cleaned_website_text'][i])
        sum_stream=sum_stream+a
print('Total number of words including all the Streaming services websites: ', sum_stream)


#Sports
sum_sports=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Sports'):
        a= len(website_df['cleaned_website_text'][i])
        sum_sports=sum_sports+a
print('Total number of words including all the sports websites: ', sum_sports)


#E-commerce
sum_commerce=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='E-Commerce'):
        a= len(website_df['cleaned_website_text'][i])
        sum_commerce=sum_commerce+a
print('Total number of words including all the E-commerce website: ', sum_commerce)



#Games
sum_game=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Games'):
        a= len(website_df['cleaned_website_text'][i])
        sum_game=sum_game+a
print('Total number of words including all the games websites: ', sum_game)



#News
sum_news=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='News'):
        a= len(website_df['cleaned_website_text'][i])
        sum_news=sum_news+a
print('Total number of words including all the News websites: ', sum_news)



#Health and Fitness
sum_health=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Health and Fitness'):
        a= len(website_df['cleaned_website_text'][i])
        sum_health=sum_health+a
print('Total number of words including all the Health and Fitness websites: ', sum_health)



#Computers and Technology
sum_comp=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Computers and Technology'):
        a= len(website_df['cleaned_website_text'][i])
        sum_comp=sum_comp+a
print('Total number of words including all the Computers and Technology website: ', sum_comp)



#Photography
sum_photog=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Photography'):
        a= len(website_df['cleaned_website_text'][i])
        sum_photog=sum_photog+a
print('Total number of words including all the Photography websites: ', sum_photog)



#Food
sum_food=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Food'):
        a= len(website_df['cleaned_website_text'][i])
        sum_food=sum_food+a
print('Total number of words including all the Food websites: ', sum_food)



#Law and Government
sum_law=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Law and Government'):
        a= len(website_df['cleaned_website_text'][i])
        sum_law=sum_law+a
print('Total number of words including all the Law and Government websites: ', sum_law)



#Social Networking and Messaging
sum_social=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Social Networking and Messaging'):
        a= len(website_df['cleaned_website_text'][i])
        sum_social=sum_social+a
print('Total number of words including all the Social Networking and Messaging website: ', sum_social)



#Adult
sum_ad=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Adult'):
        a= len(website_df['cleaned_website_text'][i])
        sum_ad=sum_ad+a
print('Total number of words including all the adult websites: ', sum_ad)



#Forums
sum_forum=0
for i in website_df['Category'].index:
    if (website_df['Category'][i]=='Forums'):
        a= len(website_df['cleaned_website_text'][i])
        sum_forum=sum_forum+a
print('Total number of words including all the Forums websites: ', sum_forum)


l=[sum_ed,sum_forum,sum_news,sum_sports,sum_health,sum_comp,sum_ad,sum_photog,sum_social,sum_law,sum_food,sum_game,sum_stream,sum_travel,sum_business,sum_commerce]
x1=pd.Series(l).to_frame()
x2=pd.Series(['Education','Business/Corporate','Travel','Streaming Services','Sports','E-Commerce','Games','News','Health & Fitness','Computer and Technology','Photography','Food','Law & Government','Social Neworking & Messaging','Adult','Forums']).to_frame()
x3=pd.concat([x2,x1],axis=1,ignore_index=True)
x3.columns=['Website category','Sum of length of all the words on the site']
x3.sort_values(by='Sum of length of all the words on the site',ascending=False)
# Out:
# Total number of words including all the educational websites:  553589
# Total number of words including all the Business/Corporate website:  387809
# Total number of words including all the travel websites:  580225
# Total number of words including all the Streaming services websites:  294427
# Total number of words including all the sports websites:  795336
# Total number of words including all the E-commerce website:  480469
# Total number of words including all the games websites:  299591
# Total number of words including all the News websites:  846094
# Total number of words including all the Health and Fitness websites:  534338
# Total number of words including all the Computers and Technology website:  410344
# Total number of words including all the Photography websites:  327144
# Total number of words including all the Food websites:  402161
# Total number of words including all the Law and Government websites:  403029
# Total number of words including all the Social Networking and Messaging website:  178485
# Total number of words including all the adult websites:  102712
# Total number of words including all the Forums websites:  50646
#                 Website category  Sum of length of all the words on the site
# 2                         Travel                                      846094
# 3             Streaming Services                                      795336
# 13  Social Neworking & Messaging                                      580225
# 0                      Education                                      553589
# 4                         Sports                                      534338
# 15                        Forums                                      480469
# 5                     E-Commerce                                      410344
# 9        Computer and Technology                                      403029
# 10                   Photography                                      402161
# 14                         Adult                                      387809
# 7                           News                                      327144
# 11                          Food                                      299591
# 12              Law & Government                                      294427
# 8               Health & Fitness                                      178485
# 6                          Games                                      102712
# 1             Business/Corporate                                       50646

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(20,6))
sns.barplot(x='Website category',y='Sum of length of all the words on the site',data=x3)
plt.xticks(rotation=75)
plt.title('Category wise total number of characters on all the websites (combined)',fontweight='bold',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Category wise total number of characters on all the websites (combined)')

# %%
X=website_df['cleaned_website_text']      
y=website_df['Category']

# %%
def text_process(value):
    nopunc=[char for char in value if char not in string.punctuation]   #Removes punctuation
    nopunc=''.join(nopunc)
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]  #Removes stopwords

# %%
X.apply(text_process).head()    #Getting the cleaned text (head of the dataframe displayed here)
# Out:
# 0    [official, site, good, hotel, accommodation, b...
# 1    [expedia, hotel, book, sites, like, use, vacat...
# 2    [tripadvisor, hotel, book, sites, like, previo...
# 3    [cheap, flights, search, compare, flights, mom...
# 4    [bot, create, free, account, create, free, acc...
# Name: cleaned_website_text, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer 
X=CountVectorizer().fit_transform(X)

# %%
from sklearn.feature_extraction.text import TfidfTransformer    
X=TfidfTransformer().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=101)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
website_class = MultinomialNB()

# %%
website_class.fit(X_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
predictions = website_class.predict(X_test)

# %%
predictions
# Out:
# array(['Law and Government', 'Streaming Services', 'Food', 'Travel',
#        'Food', 'Food', 'News', 'Food', 'Games', 'Sports', 'Games',
#        'Streaming Services', 'News', 'Food', 'Education', 'Photography',
#        'Sports', 'Travel', 'Computers and Technology', 'Education',
#        'Education', 'Sports', 'E-Commerce', 'Food', 'Education', 'Travel',
#        'News', 'Social Networking and Messaging', 'Business/Corporate',
#        'Travel', 'Social Networking and Messaging', 'Photography',
#        'Streaming Services', 'Streaming Services',
#        'Computers and Technology', 'Education', 'Games', 'Travel',
#        'Education', 'Health and Fitness', 'Education',
#        'Social Networking and Messaging', 'Streaming Services',
#        'Business/Corporate', 'Photography', 'Education',
#        'Health and Fitness', 'Travel', 'Education', 'Travel',
#        'E-Commerce', 'Business/Corporate', 'Travel', 'Travel',
#        'E-Commerce', 'E-Commerce', 'Games', 'Computers and Technology',
#        'Travel', 'Sports', 'E-Commerce', 'Sports', 'Business/Corporate',
#        'Food', 'News', 'Photography', 'Computers and Technology',
#        'Education', 'Education', 'Travel', 'Law and Government',
#        'Computers and Technology', 'Travel', 'Computers and Technology',
#        'Food', 'Streaming Services', 'Streaming Services', 'Sports',
#        'Health and Fitness', 'Business/Corporate',
#        'Social Networking and Messaging', 'Streaming Services',
#        'Computers and Technology', 'Food', 'Streaming Services', 'Travel',
#        'E-Commerce', 'Sports', 'Education', 'Health and Fitness',
#        'Health and Fitness', 'Education', 'Law and Government', 'Sports',
#        'Streaming Services', 'Education', 'Games', 'News', 'Food',
#        'Games', 'Streaming Services', 'Education', 'Streaming Services',
#        'Health and Fitness', 'Sports', 'Business/Corporate', 'News',
#        'Streaming Services', 'Computers and Technology',
#        'Social Networking and Messaging',
#        'Social Networking and Messaging', 'Health and Fitness',
#        'Business/Corporate', 'News', 'E-Commerce', 'Travel',
#        'Social Networking and Messaging', 'Health and Fitness',
#        'Law and Government', 'Sports', 'Law and Government', 'Food',
#        'Business/Corporate', 'News', 'Sports', 'Food',
#        'Business/Corporate', 'Computers and Technology',
#        'Health and Fitness', 'Streaming Services', 'Education',
#        'Photography', 'News', 'Health and Fitness', 'Health and Fitness',
#        'News', 'Law and Government', 'Games', 'News', 'Sports',
#        'Education', 'Education', 'Business/Corporate', 'Travel',
#        'Photography', 'Food', 'Photography', 'News', 'Games',
#        'Business/Corporate', 'E-Commerce', 'Computers and Technology',
#        'News', 'News', 'Games', 'Social Networking and Messaging',
#        'Social Networking and Messaging', 'Computers and Technology',
#        'Business/Corporate', 'News', 'News', 'Streaming Services', 'Food',
#        'Photography', 'Games', 'Streaming Services', 'Streaming Services',
#        'Games', 'Business/Corporate', 'Health and Fitness', 'Education',
#        'Health and Fitness', 'Health and Fitness', 'Business/Corporate',
#        'Streaming Services', 'Food', 'Sports', 'E-Commerce',
#        'Business/Corporate', 'Business/Corporate', 'Education',
#        'Law and Government', 'Health and Fitness', 'Travel', 'Education',
#        'Business/Corporate', 'Sports', 'Travel', 'Streaming Services',
#        'Business/Corporate', 'Computers and Technology', 'Travel',
#        'Social Networking and Messaging', 'E-Commerce',
#        'Law and Government', 'E-Commerce', 'Sports',
#        'Computers and Technology', 'E-Commerce', 'Food', 'Education',
#        'Business/Corporate', 'Health and Fitness', 'Streaming Services',
#        'News', 'Photography', 'Streaming Services', 'Photography',
#        'Streaming Services', 'Sports', 'E-Commerce', 'E-Commerce',
#        'E-Commerce', 'Travel', 'Photography', 'News',
#        'Business/Corporate', 'Games', 'News', 'Streaming Services',
#        'Health and Fitness', 'News', 'News', 'Computers and Technology',
#        'News', 'Law and Government', 'Social Networking and Messaging',
#        'Education', 'Social Networking and Messaging',
#        'Social Networking and Messaging', 'Travel', 'Business/Corporate',
#        'Travel', 'Streaming Services', 'Computers and Technology',
#        'Business/Corporate', 'Law and Government', 'Games',
#        'Computers and Technology', 'Travel', 'Sports', 'Sports', 'Food',
#        'Business/Corporate', 'Photography', 'Business/Corporate',
#        'Social Networking and Messaging', 'E-Commerce',
#        'Streaming Services', 'E-Commerce', 'Travel', 'Business/Corporate',
#        'Travel', 'Food', 'Streaming Services', 'Business/Corporate',
#        'Games', 'Business/Corporate', 'Business/Corporate',
#        'Health and Fitness', 'Streaming Services', 'Photography',
#        'Streaming Services', 'News', 'Business/Corporate',
#        'Health and Fitness', 'Photography', 'Education',
#        'Law and Government', 'Food', 'E-Commerce', 'E-Commerce', 'Sports',
#        'Travel', 'Streaming Services', 'News', 'Health and Fitness',
#        'Sports', 'Health and Fitness', 'E-Commerce',
#        'Social Networking and Messaging', 'News', 'Streaming Services',
#        'Games', 'Business/Corporate', 'Travel', 'News',
#        'Streaming Services', 'Photography', 'Streaming Services', 'Games',
#        'News', 'Business/Corporate', 'Business/Corporate', 'Games',
#        'Business/Corporate', 'Streaming Services', 'E-Commerce',
#        'Law and Government', 'E-Commerce', 'Business/Corporate', 'Sports',
#        'Business/Corporate', 'Games', 'Food', 'Computers and Technology',
#        'Travel', 'Education', 'Law and Government', 'Business/Corporate',
#        'Photography', 'Social Networking and Messaging', 'News', 'News',
#        'Law and Government', 'Health and Fitness', 'Games', 'E-Commerce',
#        'Social Networking and Messaging', 'Business/Corporate', 'News',
#        'Travel', 'Travel', 'News', 'Food', 'Business/Corporate',
#        'Law and Government', 'Law and Government', 'Business/Corporate',
#        'Streaming Services', 'Games', 'E-Commerce', 'Education',
#        'Business/Corporate', 'News', 'Social Networking and Messaging',
#        'Law and Government', 'Social Networking and Messaging',
#        'Health and Fitness', 'Education', 'Health and Fitness',
#        'Education', 'E-Commerce', 'Law and Government', 'Travel',
#        'Health and Fitness', 'Sports', 'Games', 'Education', 'Travel',
#        'Streaming Services', 'Social Networking and Messaging',
#        'Streaming Services', 'Sports', 'Health and Fitness', 'News',
#        'Games', 'Education', 'Business/Corporate', 'Education',
#        'Business/Corporate', 'Health and Fitness', 'Games',
#        'Business/Corporate', 'Photography', 'Photography',
#        'Business/Corporate', 'Sports', 'Business/Corporate', 'Sports',
#        'Travel', 'Photography', 'Business/Corporate', 'News',
#        'E-Commerce', 'Sports', 'Travel', 'News', 'News',
#        'Law and Government', 'Travel', 'News', 'Sports', 'Food',
#        'Education', 'Education', 'Sports', 'E-Commerce',
#        'Law and Government', 'Sports', 'Computers and Technology',
#        'Business/Corporate', 'Health and Fitness', 'Food',
#        'Health and Fitness', 'Computers and Technology',
#        'Computers and Technology', 'Business/Corporate', 'Education',
#        'News', 'E-Commerce', 'Games', 'Travel', 'Travel', 'Travel',
#        'Sports', 'Games', 'Photography', 'Photography', 'Food', 'Travel',
#        'Sports', 'Sports', 'Business/Corporate', 'Business/Corporate',
#        'News', 'Education'], dtype='<U31')

# %%
print(classification_report(predictions,y_test))
# Out:
#                                  precision    recall  f1-score   support
#
#                           Adult       0.00      0.00      0.00         0
#              Business/Corporate       1.00      0.56      0.72        50
#        Computers and Technology       0.62      0.90      0.73        20
#                      E-Commerce       0.90      0.64      0.75        28
#                       Education       0.94      0.97      0.96        35
#                            Food       0.79      0.92      0.85        24
#                          Forums       0.00      0.00      0.00         0
#                           Games       0.66      1.00      0.79        25
#              Health and Fitness       0.91      1.00      0.95        29
#              Law and Government       0.91      1.00      0.95        20
#                            News       0.92      0.56      0.70        39
#                     Photography       0.88      1.00      0.93        21
# Social Networking and Messaging       0.77      1.00      0.87        20
#                          Sports       0.97      0.97      0.97        32
#              Streaming Services       0.92      0.97      0.95        36
#                          Travel       1.00      0.82      0.90        38
#
#                        accuracy                           0.85       417
#                       macro avg       0.76      0.77      0.75       417
#                    weighted avg       0.89      0.85      0.85       417
# D:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(confusion_matrix(predictions,y_test),cmap='YlGn_r',annot=True)

# %%
print(accuracy_score(predictions,y_test))
# Out:
# 0.8489208633093526

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predictions_rfc=rfc.predict(X_test)

# %%
predictions_rfc
# Out:
# array(['Law and Government', 'Photography', 'Food', 'Travel', 'Food',
#        'E-Commerce', 'Sports', 'Food', 'Games', 'Business/Corporate',
#        'Games', 'Computers and Technology', 'News', 'Food',
#        'Law and Government', 'Photography', 'Games', 'Travel',
#        'Computers and Technology', 'Computers and Technology',
#        'Education', 'Games', 'Business/Corporate', 'Food', 'Education',
#        'Travel', 'Business/Corporate', 'Social Networking and Messaging',
#        'Business/Corporate', 'Travel', 'Social Networking and Messaging',
#        'Photography', 'Streaming Services', 'Streaming Services',
#        'Streaming Services', 'Education', 'Business/Corporate', 'Travel',
#        'Food', 'E-Commerce', 'Education', 'Games', 'Streaming Services',
#        'Business/Corporate', 'Photography', 'Education', 'Travel',
#        'Travel', 'Law and Government', 'Travel', 'Business/Corporate',
#        'Education', 'Travel', 'Travel', 'E-Commerce', 'E-Commerce',
#        'E-Commerce', 'Computers and Technology', 'Streaming Services',
#        'Sports', 'Food', 'Sports', 'Business/Corporate', 'Food', 'News',
#        'Photography', 'Computers and Technology', 'Education',
#        'Social Networking and Messaging', 'Travel', 'Law and Government',
#        'Computers and Technology', 'Travel', 'News', 'Food',
#        'Photography', 'Social Networking and Messaging', 'Sports',
#        'Health and Fitness', 'E-Commerce',
#        'Social Networking and Messaging', 'Streaming Services',
#        'Computers and Technology', 'Food', 'Streaming Services', 'Travel',
#        'E-Commerce', 'Sports', 'Education', 'Food', 'Health and Fitness',
#        'Education', 'Education', 'Games', 'Streaming Services',
#        'Law and Government', 'Games', 'News', 'Food', 'Games',
#        'Streaming Services', 'Education', 'E-Commerce',
#        'Health and Fitness', 'Sports', 'Health and Fitness',
#        'Business/Corporate', 'News', 'Computers and Technology',
#        'Social Networking and Messaging', 'E-Commerce', 'Education',
#        'Food', 'Streaming Services', 'Business/Corporate', 'Travel',
#        'Social Networking and Messaging', 'Food', 'Law and Government',
#        'Games', 'Law and Government', 'Food', 'Streaming Services',
#        'News', 'Streaming Services', 'Business/Corporate',
#        'Business/Corporate', 'Computers and Technology',
#        'Health and Fitness', 'Streaming Services', 'Business/Corporate',
#        'Photography', 'Health and Fitness', 'Business/Corporate',
#        'E-Commerce', 'News', 'Law and Government', 'Games',
#        'Streaming Services', 'Sports', 'Computers and Technology',
#        'Education', 'Business/Corporate', 'Travel', 'Photography', 'Food',
#        'Photography', 'Law and Government', 'Food', 'Business/Corporate',
#        'E-Commerce', 'Computers and Technology', 'News', 'News', 'Games',
#        'Social Networking and Messaging',
#        'Social Networking and Messaging', 'Photography',
#        'Business/Corporate', 'Adult', 'News', 'Business/Corporate',
#        'Food', 'Photography', 'Sports', 'Streaming Services',
#        'Streaming Services', 'Games', 'Computers and Technology',
#        'Health and Fitness', 'Business/Corporate', 'Health and Fitness',
#        'Business/Corporate', 'Photography', 'Food', 'Food', 'Sports',
#        'E-Commerce', 'Business/Corporate', 'Business/Corporate',
#        'Education', 'Business/Corporate', 'Health and Fitness', 'Travel',
#        'Food', 'Law and Government', 'Sports', 'Streaming Services',
#        'Streaming Services', 'Business/Corporate', 'Education', 'Travel',
#        'Social Networking and Messaging', 'E-Commerce',
#        'Streaming Services', 'Streaming Services', 'Sports',
#        'Computers and Technology', 'Photography', 'Food', 'Education',
#        'Computers and Technology', 'E-Commerce', 'Streaming Services',
#        'Education', 'Photography', 'Business/Corporate', 'Photography',
#        'Streaming Services', 'Food', 'E-Commerce', 'Adult', 'Food',
#        'Food', 'Photography', 'Education', 'Business/Corporate',
#        'Computers and Technology', 'News', 'Streaming Services',
#        'Streaming Services', 'News', 'Business/Corporate', 'Education',
#        'News', 'Business/Corporate', 'Social Networking and Messaging',
#        'E-Commerce', 'E-Commerce', 'Business/Corporate', 'Food',
#        'Computers and Technology', 'Travel', 'Games',
#        'Computers and Technology', 'Education', 'Law and Government',
#        'Games', 'Travel', 'Business/Corporate', 'Sports', 'Sports',
#        'Food', 'Games', 'Photography', 'E-Commerce',
#        'Social Networking and Messaging', 'E-Commerce',
#        'Business/Corporate', 'E-Commerce', 'Travel', 'Streaming Services',
#        'Travel', 'E-Commerce', 'Health and Fitness', 'Business/Corporate',
#        'E-Commerce', 'Business/Corporate', 'Streaming Services',
#        'Health and Fitness', 'Streaming Services', 'Photography',
#        'Streaming Services', 'Travel', 'Business/Corporate',
#        'Health and Fitness', 'Photography', 'Games', 'Law and Government',
#        'Food', 'E-Commerce', 'Education', 'Games', 'Streaming Services',
#        'Health and Fitness', 'Social Networking and Messaging',
#        'Education', 'Sports', 'Education', 'E-Commerce',
#        'Business/Corporate', 'Streaming Services', 'Streaming Services',
#        'Games', 'Business/Corporate', 'Streaming Services', 'News',
#        'Streaming Services', 'Photography', 'Food', 'Games', 'News',
#        'Business/Corporate', 'Computers and Technology', 'Food',
#        'Business/Corporate', 'Streaming Services', 'E-Commerce',
#        'Law and Government', 'Business/Corporate', 'Business/Corporate',
#        'Food', 'Business/Corporate', 'Games', 'Food',
#        'Computers and Technology', 'Travel', 'Business/Corporate',
#        'Law and Government', 'Business/Corporate', 'Photography',
#        'Social Networking and Messaging', 'Games', 'News',
#        'Law and Government', 'Business/Corporate', 'Games',
#        'Computers and Technology', 'Social Networking and Messaging',
#        'Streaming Services', 'Food', 'Travel', 'Business/Corporate',
#        'News', 'Food', 'Business/Corporate', 'E-Commerce',
#        'Business/Corporate', 'Travel', 'Streaming Services', 'Games',
#        'Photography', 'Computers and Technology', 'Law and Government',
#        'News', 'Computers and Technology', 'Law and Government',
#        'Social Networking and Messaging', 'Health and Fitness',
#        'Business/Corporate', 'Health and Fitness', 'Travel',
#        'Streaming Services', 'Law and Government', 'Travel',
#        'Health and Fitness', 'Travel', 'Games', 'Education', 'Travel',
#        'Social Networking and Messaging',
#        'Social Networking and Messaging', 'Streaming Services', 'Games',
#        'Health and Fitness', 'Sports', 'Games', 'Education',
#        'Computers and Technology', 'Business/Corporate',
#        'Business/Corporate', 'Health and Fitness', 'Games',
#        'Computers and Technology', 'Photography', 'Photography',
#        'Business/Corporate', 'Business/Corporate', 'Business/Corporate',
#        'Sports', 'Food', 'Photography', 'E-Commerce', 'Games',
#        'E-Commerce', 'E-Commerce', 'Travel', 'News', 'News',
#        'Law and Government', 'Travel', 'E-Commerce', 'Sports',
#        'Computers and Technology', 'Games', 'Business/Corporate', 'News',
#        'E-Commerce', 'Education', 'Sports',
#        'Social Networking and Messaging', 'Law and Government',
#        'E-Commerce', 'Food', 'Health and Fitness', 'Business/Corporate',
#        'Computers and Technology', 'Food', 'Education', 'Education',
#        'E-Commerce', 'Business/Corporate', 'Streaming Services', 'Travel',
#        'Travel', 'Sports', 'Games', 'Photography',
#        'Computers and Technology', 'Education', 'Travel', 'Sports',
#        'News', 'Business/Corporate', 'Streaming Services', 'Games',
#        'Games'], dtype=object)

# %%
print(classification_report(predictions_rfc,y_test))
# Out:
#                                  precision    recall  f1-score   support
#
#                           Adult       0.50      1.00      0.67         2
#              Business/Corporate       0.61      0.30      0.40        57
#        Computers and Technology       0.55      0.59      0.57        27
#                      E-Commerce       0.70      0.42      0.53        33
#                       Education       0.44      0.55      0.49        29
#                            Food       0.79      0.59      0.68        37
#                          Forums       0.00      0.00      0.00         0
#                           Games       0.47      0.56      0.51        32
#              Health and Fitness       0.50      0.84      0.63        19
#              Law and Government       0.64      0.70      0.67        20
#                            News       0.62      0.68      0.65        22
#                     Photography       0.83      0.77      0.80        26
# Social Networking and Messaging       0.58      0.79      0.67        19
#                          Sports       0.53      0.85      0.65        20
#              Streaming Services       0.58      0.55      0.56        40
#                          Travel       0.84      0.76      0.80        34
#
#                        accuracy                           0.60       417
#                       macro avg       0.57      0.62      0.58       417
#                    weighted avg       0.63      0.60      0.60       417
# D:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(confusion_matrix(predictions_rfc,y_test),cmap='PiYG',annot=True)

# %%
print(accuracy_score(predictions_rfc,y_test))
# Out:
# 0.5995203836930456

# %%
from sklearn.svm import SVC

# %%
svc=SVC()

# %%
svc.fit(X_train,y_train)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
predictions_svc=svc.predict(X_test)

# %%
predictions
# Out:
# array(['Law and Government', 'Streaming Services', 'Food', 'Travel',
#        'Food', 'Food', 'News', 'Food', 'Games', 'Sports', 'Games',
#        'Streaming Services', 'News', 'Food', 'Education', 'Photography',
#        'Sports', 'Travel', 'Computers and Technology', 'Education',
#        'Education', 'Sports', 'E-Commerce', 'Food', 'Education', 'Travel',
#        'News', 'Social Networking and Messaging', 'Business/Corporate',
#        'Travel', 'Social Networking and Messaging', 'Photography',
#        'Streaming Services', 'Streaming Services',
#        'Computers and Technology', 'Education', 'Games', 'Travel',
#        'Education', 'Health and Fitness', 'Education',
#        'Social Networking and Messaging', 'Streaming Services',
#        'Business/Corporate', 'Photography', 'Education',
#        'Health and Fitness', 'Travel', 'Education', 'Travel',
#        'E-Commerce', 'Business/Corporate', 'Travel', 'Travel',
#        'E-Commerce', 'E-Commerce', 'Games', 'Computers and Technology',
#        'Travel', 'Sports', 'E-Commerce', 'Sports', 'Business/Corporate',
#        'Food', 'News', 'Photography', 'Computers and Technology',
#        'Education', 'Education', 'Travel', 'Law and Government',
#        'Computers and Technology', 'Travel', 'Computers and Technology',
#        'Food', 'Streaming Services', 'Streaming Services', 'Sports',
#        'Health and Fitness', 'Business/Corporate',
#        'Social Networking and Messaging', 'Streaming Services',
#        'Computers and Technology', 'Food', 'Streaming Services', 'Travel',
#        'E-Commerce', 'Sports', 'Education', 'Health and Fitness',
#        'Health and Fitness', 'Education', 'Law and Government', 'Sports',
#        'Streaming Services', 'Education', 'Games', 'News', 'Food',
#        'Games', 'Streaming Services', 'Education', 'Streaming Services',
#        'Health and Fitness', 'Sports', 'Business/Corporate', 'News',
#        'Streaming Services', 'Computers and Technology',
#        'Social Networking and Messaging',
#        'Social Networking and Messaging', 'Health and Fitness',
#        'Business/Corporate', 'News', 'E-Commerce', 'Travel',
#        'Social Networking and Messaging', 'Health and Fitness',
#        'Law and Government', 'Sports', 'Law and Government', 'Food',
#        'Business/Corporate', 'News', 'Sports', 'Food',
#        'Business/Corporate', 'Computers and Technology',
#        'Health and Fitness', 'Streaming Services', 'Education',
#        'Photography', 'News', 'Health and Fitness', 'Health and Fitness',
#        'News', 'Law and Government', 'Games', 'News', 'Sports',
#        'Education', 'Education', 'Business/Corporate', 'Travel',
#        'Photography', 'Food', 'Photography', 'News', 'Games',
#        'Business/Corporate', 'E-Commerce', 'Computers and Technology',
#        'News', 'News', 'Games', 'Social Networking and Messaging',
#        'Social Networking and Messaging', 'Computers and Technology',
#        'Business/Corporate', 'News', 'News', 'Streaming Services', 'Food',
#        'Photography', 'Games', 'Streaming Services', 'Streaming Services',
#        'Games', 'Business/Corporate', 'Health and Fitness', 'Education',
#        'Health and Fitness', 'Health and Fitness', 'Business/Corporate',
#        'Streaming Services', 'Food', 'Sports', 'E-Commerce',
#        'Business/Corporate', 'Business/Corporate', 'Education',
#        'Law and Government', 'Health and Fitness', 'Travel', 'Education',
#        'Business/Corporate', 'Sports', 'Travel', 'Streaming Services',
#        'Business/Corporate', 'Computers and Technology', 'Travel',
#        'Social Networking and Messaging', 'E-Commerce',
#        'Law and Government', 'E-Commerce', 'Sports',
#        'Computers and Technology', 'E-Commerce', 'Food', 'Education',
#        'Business/Corporate', 'Health and Fitness', 'Streaming Services',
#        'News', 'Photography', 'Streaming Services', 'Photography',
#        'Streaming Services', 'Sports', 'E-Commerce', 'E-Commerce',
#        'E-Commerce', 'Travel', 'Photography', 'News',
#        'Business/Corporate', 'Games', 'News', 'Streaming Services',
#        'Health and Fitness', 'News', 'News', 'Computers and Technology',
#        'News', 'Law and Government', 'Social Networking and Messaging',
#        'Education', 'Social Networking and Messaging',
#        'Social Networking and Messaging', 'Travel', 'Business/Corporate',
#        'Travel', 'Streaming Services', 'Computers and Technology',
#        'Business/Corporate', 'Law and Government', 'Games',
#        'Computers and Technology', 'Travel', 'Sports', 'Sports', 'Food',
#        'Business/Corporate', 'Photography', 'Business/Corporate',
#        'Social Networking and Messaging', 'E-Commerce',
#        'Streaming Services', 'E-Commerce', 'Travel', 'Business/Corporate',
#        'Travel', 'Food', 'Streaming Services', 'Business/Corporate',
#        'Games', 'Business/Corporate', 'Business/Corporate',
#        'Health and Fitness', 'Streaming Services', 'Photography',
#        'Streaming Services', 'News', 'Business/Corporate',
#        'Health and Fitness', 'Photography', 'Education',
#        'Law and Government', 'Food', 'E-Commerce', 'E-Commerce', 'Sports',
#        'Travel', 'Streaming Services', 'News', 'Health and Fitness',
#        'Sports', 'Health and Fitness', 'E-Commerce',
#        'Social Networking and Messaging', 'News', 'Streaming Services',
#        'Games', 'Business/Corporate', 'Travel', 'News',
#        'Streaming Services', 'Photography', 'Streaming Services', 'Games',
#        'News', 'Business/Corporate', 'Business/Corporate', 'Games',
#        'Business/Corporate', 'Streaming Services', 'E-Commerce',
#        'Law and Government', 'E-Commerce', 'Business/Corporate', 'Sports',
#        'Business/Corporate', 'Games', 'Food', 'Computers and Technology',
#        'Travel', 'Education', 'Law and Government', 'Business/Corporate',
#        'Photography', 'Social Networking and Messaging', 'News', 'News',
#        'Law and Government', 'Health and Fitness', 'Games', 'E-Commerce',
#        'Social Networking and Messaging', 'Business/Corporate', 'News',
#        'Travel', 'Travel', 'News', 'Food', 'Business/Corporate',
#        'Law and Government', 'Law and Government', 'Business/Corporate',
#        'Streaming Services', 'Games', 'E-Commerce', 'Education',
#        'Business/Corporate', 'News', 'Social Networking and Messaging',
#        'Law and Government', 'Social Networking and Messaging',
#        'Health and Fitness', 'Education', 'Health and Fitness',
#        'Education', 'E-Commerce', 'Law and Government', 'Travel',
#        'Health and Fitness', 'Sports', 'Games', 'Education', 'Travel',
#        'Streaming Services', 'Social Networking and Messaging',
#        'Streaming Services', 'Sports', 'Health and Fitness', 'News',
#        'Games', 'Education', 'Business/Corporate', 'Education',
#        'Business/Corporate', 'Health and Fitness', 'Games',
#        'Business/Corporate', 'Photography', 'Photography',
#        'Business/Corporate', 'Sports', 'Business/Corporate', 'Sports',
#        'Travel', 'Photography', 'Business/Corporate', 'News',
#        'E-Commerce', 'Sports', 'Travel', 'News', 'News',
#        'Law and Government', 'Travel', 'News', 'Sports', 'Food',
#        'Education', 'Education', 'Sports', 'E-Commerce',
#        'Law and Government', 'Sports', 'Computers and Technology',
#        'Business/Corporate', 'Health and Fitness', 'Food',
#        'Health and Fitness', 'Computers and Technology',
#        'Computers and Technology', 'Business/Corporate', 'Education',
#        'News', 'E-Commerce', 'Games', 'Travel', 'Travel', 'Travel',
#        'Sports', 'Games', 'Photography', 'Photography', 'Food', 'Travel',
#        'Sports', 'Sports', 'Business/Corporate', 'Business/Corporate',
#        'News', 'Education'], dtype='<U31')

# %%
print(classification_report(predictions_svc,y_test))
# Out:
#                                  precision    recall  f1-score   support
#
#                           Adult       0.00      0.00      0.00         0
#              Business/Corporate       0.00      0.00      0.00         0
#        Computers and Technology       0.00      0.00      0.00         0
#                      E-Commerce       1.00      0.05      0.09       417
#                       Education       0.00      0.00      0.00         0
#                            Food       0.00      0.00      0.00         0
#                          Forums       0.00      0.00      0.00         0
#                           Games       0.00      0.00      0.00         0
#              Health and Fitness       0.00      0.00      0.00         0
#              Law and Government       0.00      0.00      0.00         0
#                            News       0.00      0.00      0.00         0
#                     Photography       0.00      0.00      0.00         0
# Social Networking and Messaging       0.00      0.00      0.00         0
#                          Sports       0.00      0.00      0.00         0
#              Streaming Services       0.00      0.00      0.00         0
#                          Travel       0.00      0.00      0.00         0
#
#                        accuracy                           0.05       417
#                       macro avg       0.06      0.00      0.01       417
#                    weighted avg       1.00      0.05      0.09       417
# D:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(confusion_matrix(predictions_rfc,y_test),cmap='YlOrBr',annot=True)

# %%
print(accuracy_score(predictions_svc,y_test))
# Out:
# 0.047961630695443645
